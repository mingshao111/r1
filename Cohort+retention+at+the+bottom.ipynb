# %%
import numpy as np
n=int(1e6)
a=np.random.rand(n)
b=np.log(a)
b
n

# %%
import re
myRegex=re.compile('regex pattern')
mo=myRegex.search('haystack string')
print(mo.group())

# %%
numberRegex=re.compile(r'\d{1,3}(,\d{3})*')
mo=numberRegex.search('i have a 64,000,000 year old egg 59,000,365')
print(mo.group())

# %%
a=[1,2,3,4]
b=[5,6,7,8]
p=[]
m=zip(a, b)
m

# %%
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
a+b
a.dtype
a.ndim

# %%
a=np.array([1,2,3,4], dtype=float)
a.dtype
c=np.array([[10,11,12], [20,21,22]])
c.dtype
c.ndim
c.shape
c.T
c.T.shape
c.shape

# %%
a=np.arange(25).reshape(5,5)
a

# %%
#blue
a[1::2,0:-1:2]
# yellow
# a[4,:]

# #red
# a[:,[1,3]]

# %%
a=np.array([0,1,2,3,4,5])
b=np.concatenate((a,a+10,a+20, a+30, a+40, a+50)).reshape(6,6)
b[3, [0,2,5]]

# %%
a=np.arange(25).reshape(5,5)
a[a%3==0]

# %%
def reverse_string(strings):
    return strings[::-1]

# %timeit reverse_string('asd')

# %%
a=np.array([1,2,3,4,5])
b=np.array([10,20,30,40,50])
e=[1,2,3,4,5]
f=[10,20,30,40,50]
a+b

g=zip(e,f)
h=[]
for i, j in g:
    h.append(i+j)
print(g)    
print(list(zip(e,f)))

# %%
from random import random
c=[random() for i in range(10000)]
min(c)

b=np.array(c)

m=np.arange(3).reshape(3,1)
n=np.arange(3)
l=[True, True, False]
m[l]

# %%
import numpy as np
import scipy.stats as stats
def sanity_check(size1, size2, significance = 0.05):
    n = size1 + size2
    confidence = 1 - significance
    z = stats.norm.ppf(confidence + significance / 2)
    confint = n * 0.5 + np.array([-1, 1]) * np.sqrt(n * 0.5 * 0.5)
    return z, confint

# %%
print(sanity_check(64454, 61818, significance = 0.05))

# %%
magic_number=6

while True:
    guess=input('Guess a numer between 1 and 10:')
    if int(guess)==magic_number:
        print('you got it')
        break

# %%
numbers=[1,2,3]

for x in numbers:
    for y in numbers:
        if x==y:
            continue
        print(x, y)

# %%
participant={
    "name": "Yuri Lowell",
    "age": 21,
    'height': 180,
    "guild": 'Brave Ves'
    
}

# %%
keys=[]
for i in participant:
    keys.append(i)

# %%
keys

# %%
keys_2=[key for key in participant]

# %%
keys_2

# %%
import requests
url="http://api.coindesk.com/v1/bpi/currentprice.json"

# %%
result=requests.get(url)

# %%
result.json()

# %%
def benchmark(func):
    import time
    def wrapper():
        start=time.time()
        func()
        end=time.time()
        print('[*] Execution time: {} seconds.'.format(end-start))
    return wrapper

# %%
@benchmark
def fetch_webpage():
    import requests
    webpage=requests.get('https://google.com')
    fetch_webpage()
    
fetch_webpage()

# %%
def benchmark(func): 
    import time 
    def wrapper(*args, **kwargs): 
        start = time.time() 
        return_value=func(*args, **kwargs)
        end = time.time() 
        print('[*] Execution time: {} seconds.'.format(end-start))
        return return_value
    return wrapper 
@benchmark 
def fetch_webpage(url): 
    import requests 
    webpage = requests.get(url) 
    return webpage.text

webpage=fetch_webpage('https://google.com')
print(webpage)

# %%
def benchmark(iters):
    def actual_decorator(func):
        import time
        
        def wrapper(*args, **kwargs):
            total = 0
            for i in range(iters):
                start = time.time()
                return_value = func(*args, **kwargs)
                end = time.time()
                total = total + (end-start)
            print('[*] Average execution time: {} seconds.'.format(total/iters))
            return return_value
        return wrapper
    return actual_decorator

# %%
class Customer(object):
    def __init__(self, name, balance=0.0):
        self.name=name
        self.balance=balance
        
    def withdraw(self, amount):
        if amount>self.balance:
            raise RuntimeError('amount greater than balance')
        self.balance-=amount
        return self.balance
    
    def deposit(self, amount):
        self.balance+=amount
        return self.balance
    
    
customer_1=Customer('abc', 100)

# %%
print(customer_1.name)

# %%
class Vehicles(object):
    
    base_sale_price=0
    
    def __init__(self, wheels, miles, make, model, year, sold_on):
        self.wheels=wheels
        self.miles.miles
        self.make=make
        self.model=model
        self.year=year
        self.sold_on=sold_on
    
    def sale_price(self):
        if self.sold_on is not None:
            return 0.0
        return 5000.0*self.wheels
    
    def purchase_price(self):
        if self.sold_on is None:
            return 0.0
        return 8000-(0.1*self.miles)

# %%
from datetime import datetime, timedelta
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from __future__ import division

tx_data=pd.read_csv('/Users/n0362948/desktop/Python learn/OnlineRetail.csv',encoding = 'unicode_escape')

# %%
tx_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
tx_data['InvoiceDate']=pd.to_datetime(tx_data['InvoiceDate'])

tx_data['InvoiceYearMonth']=tx_data['InvoiceDate'].map(lambda date: 100*date.year+date.month)

tx_data['Revenue']=tx_data['UnitPrice']*tx_data['Quantity']

tx_revenue=tx_data.groupby(['InvoiceYearMonth'])['Revenue'].sum().reset_index()

# %%
tx_data['InvoiceYearMonth'].head()
# Out:
# 0    201012
# 1    201012
# 2    201012
# 3    201012
# 4    201012
# Name: InvoiceYearMonth, dtype: int64

# %%
tx_revenue['MonthlyGrowth']=tx_revenue['Revenue'].pct_change()

# %%
tx_revenue.head()
# Out:
#    InvoiceYearMonth     Revenue  MonthlyGrowth
# 0            201012  748957.020            NaN
# 1            201101  560000.260      -0.252293
# 2            201102  498062.650      -0.110603
# 3            201103  683267.080       0.371850
# 4            201104  493207.121      -0.278163

# %%
tx_uk=tx_data.loc[tx_data['Country']=='United Kingdom',:]
tx_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10        536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11        536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
tx_monthly_active=tx_uk.groupby('InvoiceYearMonth')['CustomerID'].nunique()

# %%
tx_monthly_active
# Out:
# InvoiceYearMonth
# 201012     871
# 201101     684
# 201102     714
# 201103     923
# 201104     817
# 201105     985
# 201106     943
# 201107     899
# 201108     867
# 201109    1177
# 201110    1285
# 201111    1548
# 201112     617
# Name: CustomerID, dtype: int64

# %%
tx_monthly_sales=tx_uk.groupby('InvoiceYearMonth')['Quantity'].sum()

# %%
tx_monthly_sales
# Out:
# InvoiceYearMonth
# 201012    298101
# 201101    237381
# 201102    225641
# 201103    279843
# 201104    257666
# 201105    306452
# 201106    258522
# 201107    324129
# 201108    319804
# 201109    458490
# 201110    455612
# 201111    642281
# 201112    199907
# Name: Quantity, dtype: int64

# %%
tx_monthly_order_avg=tx_uk.groupby('InvoiceYearMonth')['Revenue'].sum()/tx_uk.groupby('InvoiceYearMonth')['InvoiceNo'].nunique()

# %%
tx_monthly_order_avg
# Out:
# InvoiceYearMonth
# 201012    359.014653
# 201101    327.285833
# 201102    324.263630
# 201103    310.603435
# 201104    272.659705
# 201105    302.311130
# 201106    302.993634
# 201107    320.566803
# 201108    348.726067
# 201109    412.448877
# 201110    371.638369
# 201111    412.080238
# 201112    421.621941
# dtype: float64

# %%
tx_min_purchase_date=tx_uk.groupby('CustomerID')['InvoiceDate'].min()

# %%
tx_min_purchase_date.columns=['CustomerID', 'MinPurcasedate']

# %%
tx_uk=pd.merge(tx_uk, tx_min_purchase_date, on='CustomerID')

# %%
tx_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536372     22632            HAND WARMER RED POLKA DOT         6
# 10        536372     22633               HAND WARMER UNION JACK         6
# 11        536373    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# ...

# %%
def New_Existing(row):
    if row['InvoiceDate_y']==row['InvoiceDate_x']:
        return 'New'
    else:
        return 'Existing'
    
    
tx_uk['Customer_type0']=tx_uk.apply(New_Existing, axis=1)

# %%
tx_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536372     22632            HAND WARMER RED POLKA DOT         6
# 10        536372     22633               HAND WARMER UNION JACK         6
# 11        536373    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# ...

# %%
tx_uk_user_type_revenue=tx_uk.groupby(['InvoiceYearMonth','Customer_type0'])['Revenue'].sum()

# %%
tx_uk_user_type_revenue.reset_index()
# Out:
#     InvoiceYearMonth Customer_type0     Revenue
# 0             201012       Existing  193566.620
# 1             201012            New  290233.120
# 2             201101       Existing  135707.280
# 3             201101            New  216274.000
# 4             201102       Existing  234696.860
# 5             201102            New  114156.770
# 6             201103       Existing  306383.090
# 7             201103            New  150534.780
# 8             201104       Existing  277852.790
# 9             201104            New   98891.621
# 10            201105       Existing  439498.050
# 11            201105            New   86075.300
# 12            201106       Existing  410597.460
# 13            201106            New   61911.790
# 14            201107       Existing  413257.340
# 15            201107            New   47890.261
# 16            201108       Existing  423032.260
# 17            201108            New   53976.150
# 18            201109       Existing  646838.041
# ...

# %%
tx_purchase=tx_uk.groupby(['CustomerID', 'InvoiceYearMonth'])['Revenue'].sum().reset_index()

# %%
tx_purchase.head()
# Out:
#    CustomerID  InvoiceYearMonth  Revenue
# 0     12346.0            201101     0.00
# 1     12747.0            201012   706.27
# 2     12747.0            201101   303.04
# 3     12747.0            201103   310.78
# 4     12747.0            201105   771.31

# %%
tx_retention=pd.crosstab(tx_purchase['CustomerID'], tx_purchase['InvoiceYearMonth'])

# %%
tx_retention.head()
# Out:
# InvoiceYearMonth  201012  201101  201102  201103  201104  201105  201106  \
# CustomerID
# 12346.0                0       1       0       0       0       0       0
# 12747.0                1       1       0       1       0       1       1
# 12748.0                1       1       1       1       1       1       1
# 12749.0                0       0       0       0       0       1       0
# 12820.0                0       1       0       0       0       0       0
#
# InvoiceYearMonth  201107  201108  201109  201110  201111  201112
# CustomerID
# 12346.0                0       0       0       0       0       0
# 12747.0                0       1       0       1       1       1
# 12748.0                1       1       1       1       1       1
# 12749.0                0       1       0       0       1       1
# 12820.0                0       0       1       1       0       1

# %%
months=tx_retention.columns[2:]

# %%
months
# Out:
# Int64Index([201102, 201103, 201104, 201105, 201106, 201107, 201108, 201109,
#             201110, 201111, 201112],
#            dtype='int64', name='InvoiceYearMonth')

# %%
retention_array=[]
for i in range(len(months)-1):
    retention_data={}
    selected_month=months[i+1]
    prev_month=months[i]
    
    retention_data['InvoiceYearMonth']=int(selected_month)
    retention_data['TotalUserCount']=tx_retention[selected_month].sum()
    retention_data['RetainedUserCount']=tx_retention.loc[((tx_retention[selected_month]>0) & (tx_retention[prev_month]>0)),:][selected_month].sum()
    retention_array.append(retention_data)

# %%
tx_retention1=pd.DataFrame(retention_array)
tx_retention1
# Out:
#    InvoiceYearMonth  RetainedUserCount  TotalUserCount
# 0            201103                305             923
# 1            201104                310             817
# 2            201105                369             985
# 3            201106                417             943
# 4            201107                379             899
# 5            201108                391             867
# 6            201109                417            1177
# 7            201110                502            1285
# 8            201111                616            1548
# 9            201112                402             617

# %%
tx_retention1['RetentionRate']=tx_retention1['RetainedUserCount']/tx_retention1['TotalUserCount']
tx_retention1
# Out:
#    InvoiceYearMonth  RetainedUserCount  TotalUserCount  RetentionRate
# 0            201103                305             923       0.330444
# 1            201104                310             817       0.379437
# 2            201105                369             985       0.374619
# 3            201106                417             943       0.442206
# 4            201107                379             899       0.421580
# 5            201108                391             867       0.450980
# 6            201109                417            1177       0.354291
# 7            201110                502            1285       0.390661
# 8            201111                616            1548       0.397933
# 9            201112                402             617       0.651540

# %%
tx_retention2 = pd.crosstab(tx_purchase['CustomerID'], tx_purchase['InvoiceYearMonth']).reset_index()

tx_retention2

tx_retention2.columns
# Out:
# Index(['CustomerID',       201012,       201101,       201102,       201103,
#              201104,       201105,       201106,       201107,       201108,
#              201109,       201110,       201111,       201112],
#       dtype='object', name='InvoiceYearMonth')

# %%
tx_retention.head()
# Out:
# InvoiceYearMonth  201012  201101  201102  201103  201104  201105  201106  \
# CustomerID
# 12346.0                0       1       0       0       0       0       0
# 12747.0                1       1       0       1       0       1       1
# 12748.0                1       1       1       1       1       1       1
# 12749.0                0       0       0       0       0       1       0
# 12820.0                0       1       0       0       0       0       0
#
# InvoiceYearMonth  201107  201108  201109  201110  201111  201112
# CustomerID
# 12346.0                0       0       0       0       0       0
# 12747.0                0       1       0       1       1       1
# 12748.0                1       1       1       1       1       1
# 12749.0                0       1       0       0       1       1
# 12820.0                0       0       1       1       0       1

# %%
tx_retention[201102].sum()
# Out:
# 714

# %%
new_column_names = [ 'm_' + str(column) for column in tx_retention2.columns]
tx_retention2.columns = new_column_names

# %%
new_column_names
# Out:
# ['m_CustomerID',
#  'm_201012',
#  'm_201101',
#  'm_201102',
#  'm_201103',
#  'm_201104',
#  'm_201105',
#  'm_201106',
#  'm_201107',
#  'm_201108',
#  'm_201109',
#  'm_201110',
#  'm_201111',
#  'm_201112']

# %%
months=tx_retention.columns
months
# Out:
# Int64Index([201012, 201101, 201102, 201103, 201104, 201105, 201106, 201107,
#             201108, 201109, 201110, 201111, 201112],
#            dtype='int64', name='InvoiceYearMonth')

# %%
#create the array of Retained users for each cohort monthly
retention_array = []
for i in range(len(months)):
    retention_data = {}
    selected_month = months[i]
    prev_months = months[:i]
    next_months = months[i+1:]
    for prev_month in prev_months:
        retention_data[prev_month] = np.nan
        
    total_user_count =  retention_data['TotalUserCount'] = tx_retention2['m_' + str(selected_month)].sum()
    retention_data[selected_month] = 1 
    
    query = "{} > 0".format('m_' + str(selected_month))
    

    for next_month in next_months:
        query = query + " and {} > 0".format(str('m_' + str(next_month)))
        retention_data[next_month] = np.round(tx_retention2.query(query)['m_' + str(next_month)].sum()/total_user_count,2)
    retention_array.append(retention_data)
    
tx_retention2 = pd.DataFrame(retention_array)
tx_retention2.index = months

#showing new cohort based retention table
tx_retention2
# Out:
#                   TotalUserCount  201012  201101  201102  201103  201104  \
# InvoiceYearMonth
# 201012                       871     1.0    0.37    0.21    0.16    0.12
# 201101                       684     NaN    1.00    0.38    0.26    0.18
# 201102                       714     NaN     NaN    1.00    0.43    0.23
# 201103                       923     NaN     NaN     NaN    1.00    0.34
# 201104                       817     NaN     NaN     NaN     NaN    1.00
# 201105                       985     NaN     NaN     NaN     NaN     NaN
# 201106                       943     NaN     NaN     NaN     NaN     NaN
# 201107                       899     NaN     NaN     NaN     NaN     NaN
# 201108                       867     NaN     NaN     NaN     NaN     NaN
# 201109                      1177     NaN     NaN     NaN     NaN     NaN
# 201110                      1285     NaN     NaN     NaN     NaN     NaN
# 201111                      1548     NaN     NaN     NaN     NaN     NaN
# ...

# %%
query
# Out:
# 'm_201112 > 0'

# %%
retention_array
# Out:
# [{'TotalUserCount': 871,
#   201012: 1,
#   201101: 0.37,
#   201102: 0.20999999999999999,
#   201103: 0.16,
#   201104: 0.12,
#   201105: 0.10000000000000001,
#   201106: 0.089999999999999997,
#   201107: 0.080000000000000002,
#   201108: 0.080000000000000002,
#   201109: 0.070000000000000007,
#   201110: 0.059999999999999998,
#   201111: 0.059999999999999998,
#   201112: 0.050000000000000003},
#  {201012: nan,
#   'TotalUserCount': 684,
#   201101: 1,
#   201102: 0.38,
#   201103: 0.26000000000000001,
#   201104: 0.17999999999999999,
#   201105: 0.14999999999999999,
#   201106: 0.13,
#   201107: 0.12,
#   201108: 0.11,
#   201109: 0.10000000000000001,
#   201110: 0.080000000000000002,
#   201111: 0.080000000000000002,
#   201112: 0.070000000000000007},
#  {201012: nan,
#   201101: nan,
#   'TotalUserCount': 714,
#   201102: 1,
#   201103: 0.42999999999999999,
#   201104: 0.23000000000000001,
#   201105: 0.19,
#   201106: 0.16,
#   201107: 0.14000000000000001,
#   201108: 0.12,
# ...

# %%
retention_data
# Out:
# {201012: nan,
#  201101: nan,
#  201102: nan,
#  201103: nan,
#  201104: nan,
#  201105: nan,
#  201106: nan,
#  201107: nan,
#  201108: nan,
#  201109: nan,
#  201110: nan,
#  201111: nan,
#  'TotalUserCount': 617,
#  201112: 1}
